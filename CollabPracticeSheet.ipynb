# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhbhatia57/DeployTest/blob/main/CollabPracticeSheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Mon Dec  6 09:03:02 2021

# %% [markdown]
# Text Section

# %% [markdown]
# Ploting graph using matplotlib

# %%
import numpy as np
from matplotlib import pyplot as plt
y = np.random.randn(200)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where = (y > 195), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()

# %% [markdown]
# Just another Code

# %%
print("Hello World!")
# Out:
# Hello World!
